# %% [markdown]
# <a href="https://colab.research.google.com/github/pranuk050-pixel/Npraveen_DE2026/blob/main/class_6_control_structure_and_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
if x<5:
  print("test")

# %%
x>5
# Out:
# True

# %%
x=int(float(input()))
if x%2==0:
   print("test")
# Out:
# 20.6
# test

# %%
if True:
  print("test")
# Out:
# test

# %%
if 0:
  print("True")

# %%
#condition=(False and False )
string=input()
condition1 = len(string)>10
condition2 = len(string)%2==0
condition=not(condition1 or condition2)
if condition:
  print("test")
# Out:
# datascience machine

# %%
if True:
  print("if block")
else:
  print("else block")

# %%
x=input()
if len(x)>10:
  print(x.upper())
else:
  print(x.title())
# Out:
# da sc
# Da Sc

# %%
marks=int(input())
if marks>60:
  print("grade1")
else:
  print("grade 2")
if condition true execute if block else execute else block
# Out:
# 10
# grade 2

# %%
from re import escape
x="datasce#$$#"
if x.isalpha():  ## True
  if len(x)>10:
    print("data science")
  else:
    print("data engineering")
else:
  print("machine learning")
# Out:
# machine learning

# %%
from types import BuiltinFunctionType
if True
  block 1
  if True
    Block 3
  else
    block 4
else
  block2

# %%
name=input()
matchtype=input()
if name=="kohli" :
  if matchtype=="odi":
    print("india wins")
  else:
    print("NA")
else:
  print("waste of watching cricket")
# Out:
# kohli
# test
# NA

# %%
if condition :
elif condition :
else:

# %%
x="data"
if len(x)>10: #True
  print(x)
elif x.isupper(): ### Second False
  print(x.upper())
else:
  print(len(x))
# Out:
# 4

# %%
x="daTA "
if len(x)>10: ### True
  print(x.upper())

elif x.isalpha():
  if x.isnumeric():
    print(x.title())
  else:
    print("test")
else:
  print(x.lower())
  if x.isnumeric():
    print(x.title())
  else:
    print("test")
# Out:
# data
# test

# %%
x="daTA "
if len(x)>10: ### True
  print(x.upper())

elif x.isalpha():
  if x.isnumeric():
    print(x.title())
  else:
    print("test")
else:
  print(x.lower())
  if x.isnumeric():
    print(x.title())
  else:
    print("test")

# %%
### for loop

# %%
"datasa".split("a")
# Out:
# ['d', 't', 's', '']

# %%
for i in "datasa".split("a"):
  print(i.upper())
# Out:
# D
# T
# S

# %%
"data science".split()
# Out:
# ['data', 'science']

# %%
string="abcd!!$!$"
for i in string:
  if not(i.isalpha()):
    print(i,end=' ')
# Out:
# ! ! $ ! $

# %%
3*"*"
# Out:
# '***'

# %%
for i in range(1,6):
  print((6-i)*"*")
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(10,1,-2):
  print(i,end=",")
# Out:
# 10,8,6,4,2,

# %%
max(range(1,7))
# Out:
# 6

# %%
review=''' I am writing this review after a month's usage of this cooler. I bought this because I do not want a full fledge refrigerator. I want it to be portable, meaning when I move to some place I want carry it in a car. I also want absolute zero maintenance, no defrosting or water disposal. The need is also just to store water bottles, cool drinks or milk and some snacks overnight. I also do NOT want to store medicines, dairy product for long, egg, ice creams etc that needs proper refrigeration.

So this came as a good option and my expectation are exactly matched. The cooling is efficient unlike some of the reviews here. It will never be ice cold but that is exactly want I want. Buy if you want a branded cooler that does not over cool your food and water. '''

# %%
len(review)
# Out:
# 761

# %%
len(review.split())
# Out:
# 144

# %%
for i in review.split():                         #iteration i will iterate element by element
  if len(i)%2==0 and i.startswith("a"):
    print(i)
# Out:
# am
# also
# absolute
# also
# also
# as

# %%
for i in review.split():                 #.Split() will split the review(sentence as words )
  if not(i.isalpha()):
    print(i,end=",")
# Out:
# month's,cooler.,refrigerator.,portable,,car.,maintenance,,disposal.,bottles,,overnight.,medicines,,long,,egg,,refrigeration.,matched.,here.,want.,water.,

# %%
word_count=0
for i in review.split()[0:4]:
  before_increase_count=word_count
  word_count=word_count+1
  print(before_increase_count,word_count)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
