# %% [markdown]
# <a href="https://colab.research.google.com/github/pranuk050-pixel/Python_learning-consepts/blob/main/20_07_26_python_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Operators
### math module
### functions
### map,filter, reduce

==================
loops
math module
functions (Friday sprint)

### numpy
### pandas

# %%
### Arithmetic operators
### Assignment Operators
### comparision operators
### logical operators
### identity operators
### membership operators
### bitwise operators

# %%
Addition, Subtaction, Mul,Div, Mod, Floor Divide

# %%
x=2
y=3
print(x+y)
# Out:
# 5

# %%
x=2
y=3
print(x-y)
# Out:
# -1

# %%
x=2
y=3
print(x*y)
# Out:
# 6

# %%
x=2
y=3
print(x**y) ### power ### exponent
# Out:
# 8

# %%
x=10
y=4
x/y
# Out:
# 2.5

# %%
x=10
y=4
x%y   ## remainder
# Out:
# 2

# %%
x=-2
y=4
x//y   ## floor division
# Out:
# -1

# %%
from os.path import ALLOW_MISSING
### Assignment operators
= assignment
+= add assign
-=  subtract and assign
*= multiple and assign

# %%
x=10
#y=3
x+=1   ## x=x+1
print(x)
# Out:
# 11

# %%
x=26
x-=10
print(x)
# Out:
# 16

# %%
x=10  ## declaration
x+=22  ## add and assign
x-=10  ## subtract and assign
print(x)
# Out:
# 22

# %%
x=10
x//=3
x+=10
print(x)
# Out:
# 13

# %%
x=10
x**=3
x+=10
print(x)
# Out:
# 1010

# %%
x=20
x%=6
x+=10
print(x)
# Out:
# 12

# %%
### relational operators
equal to
<
>
<=
>=
!=
==

# %%
x=10
y=20

# %%
print(x<y)
# Out:
# True

# %%
print(x<=y)
# Out:
# True

# %%
print(x>y)
# Out:
# False

# %%
print(x>=y)
# Out:
# False

# %%
print(x!=y)
# Out:
# True

# %%
print(x==y)
# Out:
# False

# %%
###3 logical

# %%
and , or, not

# %%
x=20
print(x>10 and x<25)
print(x<10 and x<25)
print(x<10 and x>25)
print(x>10 and x>25)
# Out:
# True

# %%
x=20
print(x>10 or x<25)
print(x<10 or x<25)
print(x<10 or x>25)
print(x>10 or x>25)
# Out:
# True
# True
# False
# True

# %%
x=20
print(not(x>10 or x<25)) ## true
print(not(x<10 or x<25)) ### true
print(not(x<10 or x>25))  ### false
print(not(x>10 or x>25))   ### true
# Out:
# False
# False
# True
# False

# %%
### identity operators
  is  : Retruns True if both variables refer to same object (same memory location)
  is not Retruns True if both varaibles refer to different object

# %%
a=[1,2,3]
b=a.copy()
a is not b
# Out:
# True

# %%
a=[1,2,3]
b=[1,2,3]
print(a==b)
print(a is b)
# Out:
# True
# False

# %%
### membership operators

# %%
in  : returns True if the value exists
not in  : Returns True if the value doesn`t exists

# %%
x=[1,2,3,5,6,"data"]
6 not in x
# Out:
# False

# %%
bin(5)
# Out:
# '0b101'

# %%
# 5 : 0101
# 3 : 0011
# ###0111
# Out:
#   File "/tmp/ipykernel_966/2414843201.py", line 1
#     5 : 0101
#         ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
5 | 3
# Out:
# 7

# %%
print(bin(5))
print(bin(3))
# Out:
# 0b101
# 0b11

# %%
1100
1010
or : 1110
and : 1000
xor : 0110

# %%
12 ^ 10
# Out:
# 6

# %%
print(12 | 10)
print(12 & 10)
# Out:
# 14
# 8

# %%
Xor  : Returns 1 when bits are differnt

# %%
import math

# %%
x=25
math.sqrt(25)
# Out:
# 5.0

# %%
math.floor(2.6)
# Out:
# 2

# %%
math.ceil(2.6)
# Out:
# 3

# %%
math.fabs(-10)  ## absolute value
# Out:
# 10.0

# %%
base 2
base 10

# %%
32, 2 to 5
100 10 to 2

# %%
log

# %%
math.log2(32)
# Out:
# 5.0

# %%
2**2.24524
# Out:
# 4.741159735327067

# %%
math.log2(4.741159735327067)
# Out:
# 2.24524

# %%
2,10

# %%
math.e
# Out:
# 2.718281828459045

# %%
2.718281828459045**22
# Out:
# 3584912846.1315875

# %%
math.log(45)
# Out:
# 3.8066624897703196

# %%
math.e**3.8066624897703196
# Out:
# 44.999999999999986

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.inf
# Out:
# inf

# %%
math.tau
# Out:
# 6.283185307179586
